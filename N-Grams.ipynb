# %%
def generate_ngrams(tokens, n):
  """GeneratesN-grams froma list of tokens."""
  ngrams_list = []
  for i in range(len(tokens) - n + 1):
    ngram= tuple(tokens[i:i+n])
    ngrams_list.append(ngram)
  return ngrams_list

# %%
text = "N-grams are contiguous sequences of Nitems."
tokens = text.lower().split()
print("---N-Grams (Pure Python) ---")
bigrams = generate_ngrams(tokens, 2)
print("Bigrams:", bigrams)
trigrams = generate_ngrams(tokens, 3)
print("\nTrigrams:", trigrams)
# Out:
# ---N-Grams (Pure Python) ---
# Bigrams: [('n-grams', 'are'), ('are', 'contiguous'), ('contiguous', 'sequences'), ('sequences', 'of'), ('of', 'nitems.')]
#
# Trigrams: [('n-grams', 'are', 'contiguous'), ('are', 'contiguous', 'sequences'), ('contiguous', 'sequences', 'of'), ('sequences', 'of', 'nitems.')]
